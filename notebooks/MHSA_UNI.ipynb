# %%
import os
import anndata
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

from utils.visattn import *

# %%
im_pt = "/scratch_tmp/prj/cb_normalbreast/prj_NBTClassifier/SGK_patch512/K106560/epithelials"
patch = Image.open(im_pt)
plt.imshow(patch)
plt.axis('off')

# %%
th_attn, attentions = get_attentions_lastlayer(patch, threshold=0.6)
plot_multiple(img_list = attentions, caption_list= [f"head_{i}" for i in range(12)], 
              grid_x=3, grid_y=4, figure_size=(10, 8), cmap = "hot", save_pt=None)
# Out:
# torch.Size([16, 196])
